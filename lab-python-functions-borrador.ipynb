# %% [markdown]
# ## Exercise: Managing Customer Orders with Functions
#
# In the previous exercise, you improved the code for managing customer orders by using loops and flow control. Now, let's take it a step further and refactor the code by introducing functions.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.
#
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names using a loop. The function should return the `customer_orders` set.
#
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
#
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
#
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.
#
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.
#
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.
#
# Hints for functions:
#
# - Consider the input parameters required for each function and their return values.
# - Utilize function parameters and return values to transfer data between functions.
# - Test your functions individually to ensure they work correctly.

# %%
# Lab | Functions

# %%
##Define una función llamada initialize_inventory que tome «products» como parámetro. 
#Dentro de la función, implementa el código para inicializar el diccionario «inventory» utilizando un bucle y la entrada del usuario.

# %%
#1
inventory = {}
products = ["tshirt", "mug", "hat", "book", "keychain"]
def initialize_product(products):
    for product in products:
        inventory[product] = int(input (f"""Add the {product} ammount"""))
        print (f"""You added {inventory[product]} units of {product}""")
    return inventory

# %%
initialize_product(products)
# Out:
# Add the tshirt ammount 10
# You added 10 units of tshirt
# Add the mug ammount 15
# You added 15 units of mug
# Add the hat ammount 100
# You added 100 units of hat
# Add the book ammount 3
# You added 3 units of book
# Add the keychain ammount 5
# You added 5 units of keychain
# {'tshirt': 10, 'mug': 15, 'hat': 100, 'book': 3, 'keychain': 5}

# %%
#2
customer_orders = set()
def get_customer_orders ():
    input_prod = input("Type a product:").lower()
    
    while input_prod not in products:
        print ("¡NOT VALID!")
        input_prod = input("Type a product: ").lower()
    else:
        customer_orders.add(input_prod)
        print (f"""{input_prod} added to order""")
        add_prod = input ("Do you want to add a product? y/n:").lower()
        while add_prod == "y":
            input_prod = input("Type a product:").lower()
            while input_prod not in products:
                print ("¡NOT VALID!")
                input_prod = input("Type a product: ").lower()
            else:
                customer_orders.add(input_prod)
                print (f"""{input_prod} added to order""")
                add_prod = input ("Do you want to add a product? y/n:").lower()
        else:
            print ("Thanks")
        
    return customer_orders

# %%
get_customer_orders()
# Out:
# Type a product: hat
# hat added to order
# Do you want to add a product? y/n: y
# Type a product: mug
# mug added to order
# Do you want to add a product? y/n: keychain
# Thanks
# {'hat', 'mug'}

# %%
#3
def update_inventory(customer_orders, inventory):
    for purchase in customer_orders:
        inventory[purchase] = inventory[purchase] - 1
    return inventory

# %%
update_inventory(customer_orders, inventory)
# Out:
# {'tshirt': 6, 'mug': 10, 'hat': 99, 'book': 3, 'keychain': 1}

# %%
#4
def calculate_order_statistics (customer_orders, products):
    
    total_products_ordered = len(customer_orders)
    per_unq_prod = (total_products_ordered / len (products))*100
    order_statistics = [total_products_ordered, per_unq_prod]
    return order_statistics

# %%
order_statistics = calculate_order_statistics(customer_orders, products)

# %%
#5
def print_order_statistics (order_statistics):
    print("Total products ordered: ", order_statistics[0])
    print("Percentage of unique products ordered: ", order_statistics[1], "%")

# %%
print_order_statistics(order_statistics)
# Out:
# Total products ordered:  2
# Percentage of unique products ordered:  40.0 %

# %%
#6
def print_inventory (inventory):
    for product in inventory.items():
        print (product)

# %%
print_inventory (inventory)
# Out:
# ('tshirt', 6)
# ('mug', 10)
# ('hat', 99)
# ('book', 3)
# ('keychain', 1)

# %%
product = input("Add a product?").lower()
def initialize_product(product):
    inventory = {}
    inventory[product] = input("amount")
    while first_req == "y": 
        print ("ok")
        first_req = input("Do you want to add another product? Y/N: ").lower()
    
    
    else: 
        print("Thanks")
initialize_product()

# %%
def initialize_product(first_req = input("Do you want to add product? Y/N:").lower()):
    inventory = {}
    while first_req == "y":
        print ("ok")
        first_req = input("Do you want to add another product? Y/N: ").lower()
    
    
    else: 
        print("Thanks")
initialize_product()
# Out:
# Do you want to add product? Y/N: y
# ok
# Do you want to add another product? Y/N:  n
# Thanks

# %%
def initialize_product(product = input("Add a product?").lower()):
    inventory = {}
    inventory[product] = input("amount")
    while first_req == "y": 
        print ("ok")
        first_req = input("Do you want to add another product? Y/N: ").lower()
    
    
    else: 
        print("Thanks")
initialize_product()
# Out:
# Do you want to add a product? Y/N:  y
# ok
# Do you want to add a product? Y/N:  n
# Thanks

# %%
inventory = {}
def initialize_product(product = input("Add a product?").lower()):
    
    inventory[product] = input("amount")
    return inventory
# Out:
# Add a product? jabon

# %%
inventory = {}
def initialize_product(first_req = input("Do you want to add a product? Y/N: ").lower()):
    while first_req == "y":
        print ("ok")
        first_req = input("Do you want to add a product? Y/N: ").lower()
    
    
    else: 
        print("Thanks")
initialize_product()
# Out:
# Do you want to add a product? Y/N:  y
# ok
# Do you want to add a product? Y/N:  y
# ok
# Do you want to add a product? Y/N:  n
# Thanks

# %%
inventory = {}
def update_inventory (products):
    while add_product == "y":
        add_product = input("Do you want to add a product? Y/N: ").lower()
        new_product = input("Please type the item:").lower()
        inventory[new_product] = int(input (f"Insert the {product} quantity"))
        print("you added: ", inventory[new_product], "units of", new_product)
    else:
        print("bye")

# %%
customer_orders = set()
add_prod = input ("Do you want to add a product? y/n").lower()
while add_prod == "y":
    input_prod = input(("Type a product:"))
    while input_prod not in products:
        print ("¡NOT VALID!")
        input_prod = input("Type a product: ").lower()
    else :
        customer_orders.add(input_prod)
        add_prod = input ("Do you want to add a product? y/n").lower()
else:
    print("BYE!")

# %%
add_product ="y"

while add_product == "y":
    
    add_product ="y"
    add_product = input("Do you want to add a product? Y/N: ").lower()
# Out:
# Do you want to add a product? Y/N:  Y
# Do you want to add a product? Y/N:  Y
# Do you want to add a product? Y/N:  N

# %%
new_product = input("Please type the item:").lower()
# Out:
# Please type the item: caca

# %%
inventory = {}
def initialize_product(new_product = input("Add a product: ").lower()):
    while new_product != "end" or new_product ==" " :
        inventory[new_product] = int(input (f"Insert the {new_product} quantity"))
        print("you added: ", inventory[new_product], "units of", new_product)
        new_product = input("Add a product: ").lower()
    
    else: 
        print("Thanks")
        return (inventory)
initialize_product()
# Out:
# Add a product:  END
# Thanks
# {}

# %%
print ("Joya")
# Out:
# Joya

# %%
dicc = {}
while elem != "":
    elem = input("x")
    dicc[elem] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 dicc = {}
# ----> 2 while elem != "":
#       3     elem = input("x")
#       4     dicc[elem] = 1
#
# NameError: name 'elem' is not defined

# %%
print(dicc)
# Out:
# {'torre': 1, 'alfil': 2}
