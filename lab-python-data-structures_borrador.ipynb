# %%
# Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
###### Paso 1- Lista de productos
products = ["t-shirt", "mug", "hat", "book", "keychain"]

#Paso 2 - Diccionario vacio
inventory = {}

#Paso 3 - Popular el diccionario con los elementos de la lista como keys y valores pedidos al usuario
inventory [products[0]] = int(input (f"Insert the {products[0]} quantity"))
inventory [products[1]] = int(input (f"Insert the {products[1]} quantity"))
inventory [products[2]] = int(input (f"Insert the {products[2]} quantity"))
inventory [products[3]] = int(input (f"Insert the {products[3]} quantity"))
inventory [products[4]] = int(input (f"Insert the {products[4]} quantity"))

#Paso 4 - Crear el Set de customer order
Customer_orders = set()

#Paso 5 - Agregar al customer order 3 items que quiera
print(""" Products:
- t-shirt
- mug
- hat
- book 
- keychain""")
Customer_orders.add(input ("Please add a product:").lower())
Customer_orders.add(input ("Please add a product:").lower())
Customer_orders.add(input ("Please add a product:").lower())

#Paso 6 Print Customer order

print ("The next products where ordered: ", Customer_orders)

#Paso 7 Clacular total de productos en la orden / % de productos ordenados respecto al total / crear un tupple con las estadisticas 
total_products_ordered = len(Customer_orders) 
total_inventory = inventory["t-shirt"] + inventory["mug"] + inventory["hat"] + inventory["book"] + inventory["keychain"]
ordered_vs_total = (total_products_ordered*100/total_inventory)

order_status = (total_products_ordered, ordered_vs_total)

# Paso 8 print order statics
print( f"""
Order Statistics:
Total Products Ordered: {total_products_ordered}
Percentage of Products Ordered: {ordered_vs_total}% 
""")

#Paso 9 quitar 1 de c/ elemento pedido del inventario
inventory ["t-shirt"] = inventory ["t-shirt"] - 1
inventory ["mug"] = inventory ["mug"] - 1
inventory ["hat"] = inventory ["hat"] - 1
inventory ["book"] = inventory ["book"] - 1
inventory ["keychain"] = inventory ["keychain"] - 1

#Paso 10 imprimir cada elemento con stock actualizado
print( f""" Your actual inventory is: 
t-shirt: {inventory ["t-shirt"]}
mug: {inventory ["mug"]}
hat: {inventory ["hat"]}
book: {inventory ["book"]}
keychain: {inventory ["keychain"]}
)"""
# Out:
# Insert the t-shirt quantity 15
# Insert the mug quantity 8
# Insert the hat quantity 13
# Insert the book quantity 7
# Insert the keychain quantity 12
#  Products:
# - t-shirt
# - mug
# - hat
# - book
# - keychain
# Please add a product: mug
# Please add a product: keychain
# Please add a product: hat
# The next products where ordered:  {'mug', 'keychain', 'hat'}
#
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 5.454545454545454%
#
#  Your actual inventory is:
# t-shirt: 14
# mug: 7
# hat: 12
# book: 6
# keychain: 11

# %%
total_products_ordered = len(Customer_orders)

total_inventory

# %%
print(total_products_ordered)
# Out:
# 3

# %%
print(inventory)
# Out:
# {'t-shirt': 100, 'mug': 350, 'hat': 460, 'book': 180, 'keychain': 60}

# %%
print (inventory)
# Out:
# {'t-shirt': 100, 'mug': 350, 'hat': 460, 'book': 180, 'keychain': 60}

# %%
total_inventory = inventory["t-shirt"] + inventory["mug"] + inventory["hat"] + inventory["book"] + inventory["keychain"]
print (total_inventory)
# Out:
# 1150

# %%
ordered_vs_total = (total_products_ordered*100/total_inventory)

# %%
print (ordered_vs_total , "%")
# Out:
# 0.2608695652173913 %

# %%
order_status = (total_products_ordered, ordered_vs_total)

# %%
print (order_status)
# Out:
# (3, 0.2608695652173913)

# %%
print( f"""
Order Statistics:
Total Products Ordered: {total_products_ordered}
Percentage of Products Ordered: {ordered_vs_total}% 
""")
# Out:
# Order Statistics:
# Total Products Ordered: 3
# Percentage of Products Ordered: 0.2608695652173913%

# %%
inventory ["t-shirt"] = inventory ["t-shirt"] - 1
inventory ["mug"] = inventory ["mug"] - 1
inventory ["hat"] = inventory ["hat"] - 1
inventory ["book"] = inventory ["book"] - 1
inventory ["keychain"] = inventory ["keychain"] - 1

# %%
print (inventory)
# Out:
# {'t-shirt': 97, 'mug': 349, 'hat': 459, 'book': 179, 'keychain': 59}

# %%
print( f""" Your actual inventory is: 
t-shirt: {inventory ["t-shirt"]}""")
# Out:
#  Your actual inventory is:
# t-shirt: 97
