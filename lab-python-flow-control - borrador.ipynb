# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
#ex. 1
###### Paso 1- Lista de productos
products = ["tshirt", "mug", "hat", "book", "keychain"]

#Paso 2 - Diccionario vacio
inventory = {}

#Paso 3 - Popular el diccionario con los elementos de la lista como keys y valores pedidos al usuario
for listed_product in products:
    inventory [listed_product] = int(input (f"Insert the {listed_product} quantity"))

#Paso 4 - Crear el Set de customer order
customer_orders = set()

#Paso 5y6 - Agregar al customer order 3 items que quiera y Print Customer order

product_number = 0
for item in products:
    print(item)

while product_number < 3:
    customer_orders.add(input ("Please add a product:").lower())
    product_number = product_number + 1
else:
    print("The next products where ordered: ", customer_orders)


#Paso 7 Clacular total de productos en la orden / % de productos ordenados respecto al total / crear un tupple con las estadisticas 
total_products_ordered = len(customer_orders) 
total_inventory = inventory["tshirt"] + inventory["mug"] + inventory["hat"] + inventory["book"] + inventory["keychain"]
ordered_vs_total = (total_products_ordered*100/total_inventory)

order_status = (total_products_ordered, ordered_vs_total)

# Paso 8 print order statics
print( f"""
Order Statistics:
Total Products Ordered: {total_products_ordered}
Percentage of Products Ordered: {ordered_vs_total}% 
""")

#Paso 9 quitar 1 de c/ elemento pedido del inventario
for purchase in customer_orders:
    inventory [purchase] = inventory [purchase] - 1

#Paso 10 imprimir cada elemento con stock actualizado
for item, stock in inventory.items():
    print("*", item, "-", stock)

# %%
#ex.2 HAY QUE CAMBIAR LAS T-SHIRT POR TSHIRT

customer_orders = set()
add_prod = input ("Do you want to add a product? y/n").lower()
while add_prod == "y":
    input_prod = input(("Type a product:"))
    while input_prod not in products:
        print ("¡NOT VALID!")
        input_prod = input("Type a product: ").lower()
    else :
        customer_orders.add(input_prod)
        add_prod = input ("Do you want to add a product? y/n").lower()
else:
    print("BYE!")

# %%
#ex 3
for purchase in customer_orders:
    inventory [purchase] = inventory [purchase] - 1

# %%
add_prod = " "

print ("Do you want to add a product? y/n")
input (add_prod).lower()
while add_prod == "y":
    input("Please type the product:")
    
    
    and add_prod != "n":
    print("Pleas add a valid option! y or n")

while add_prod == "y":
    print ("Do you want to add another product? Y/N")
    input (add_prod).lower()

print ("Thanks!")
# Out:
# Do you want to add a product? y/n
#   y
# Thanks!

# %%
customer_orders = set()
add_prod = input ("Do you want to add a product? y/n").lower()
while add_prod == "y":
    input_prod = input(("Type a product:"))
    while input_prod not in products:
        print ("¡NOT VALID!")
        input_prod = input("Type a product: ").lower()
    else :
        customer_orders.add(input_prod)
        add_prod = input ("Do you want to add a product? y/n").lower()
else:
    print("BYE!")
# Out:
# Do you want to add a product? y/n y
# Type a product: ka
# ¡NOT VALID!
# Type a product:  mug
# Do you want to add a product? y/n y
# Type a product: hat
# Do you want to add a product? y/n n
# BYE!

# %%
print (type(customer_orders))
# Out:
# <class 'set'>

# %%
products = ["tshirt", "mug", "hat", "book", "keychain"]
input_prod = input("Type a product: ").lower()
while input_prod not in products:
    print ("Not valid")
    input_prod = input("Type a product: ").lower()
else :
    print("OK")
# Out:
# Type a product:  jamon
# Not valid
# Type a product:  TSHIRT
# OK

# %%
print(customer_orders)
# Out:
# {'mug', 'hat'}

# %%
###### Paso 1- Lista de productos
products = ["t-shirt", "mug", "hat", "book", "keychain"]

#Paso 2 - Diccionario vacio
inventory = {}

#Paso 3 - Popular el diccionario con los elementos de la lista como keys y valores pedidos al usuario (Quitar repeticiones)
for listed_product in products:
    inventory [products[0]] = int(input (f"Insert the {products[0]} quantity"))
# Out:
# Insert the t-shirt quantity 3
# Insert the t-shirt quantity 4
# Insert the t-shirt quantity 5
# Insert the t-shirt quantity 67
# Insert the t-shirt quantity 9

# %%
print (inventory)
# Out:
# {'t-shirt': 12, 'mug': 51, 'hat': 63, 'book': 78, 'keychain': 15}

# %%
products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = {}

for listed_product in products:
    inventory [listed_product] = int(input (f"Insert the {listed_product} quantity"))
# Out:
# Insert the t-shirt quantity 12
# Insert the mug quantity 51
# Insert the hat quantity 63
# Insert the book quantity 78
# Insert the keychain quantity 15

# %%
customer_orders = set()
product_number = 0

print(""" Products:
- t-shirt
- mug
- hat
- book 
- keychain""")

while product_number < 3:
    customer_orders.add(input ("Please add a product:").lower())
    product_number = product_number + 1
else:
    print(customer_orders)
# Out:
#  Products:
# - t-shirt
# - mug
# - hat
# - book
# - keychain
# Please add a product: t-shirt
# Please add a product: book
# Please add a product: keychain
# {'keychain', 'book', 't-shirt'}

# %%
#Paso 9 quitar 1 de c/ elemento pedido del inventario
for purchase in customer_orders:
    inventory [purchase] = inventory [purchase] - 1

print(inventory)
# Out:
# {'t-shirt': 7, 'mug': 50, 'hat': 62, 'book': 73, 'keychain': 10}

# %%
for inv_key in inventory.key
( f""" Your actual inventory is: 
t-shirt: {inventory ["t-shirt"]}
mug: {inventory ["mug"]}
hat: {inventory ["hat"]}
book: {inventory ["book"]}
keychain: {inventory ["keychain"]}
)"""

# %%
for item, stock in inventory.items():
    print("*", item, "-", stock)
# Out:
# * t-shirt - 7
# * mug - 50
# * hat - 62
# * book - 73
# * keychain - 10

# %%
print(inventory)
# Out:
# {'t-shirt': 7, 'mug': 50, 'hat': 62, 'book': 73, 'keychain': 10}
