# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# In the previous exercise, you developed a program to manage customer orders and inventory. Now, let's take it a step further and incorporate comprehension into your code.
#
# Follow the steps below to complete the exercise:
#
# 1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
#
#     - *Hint: Apply it to initialize inventory, updating the inventory and printing the updated inventory.*
#
#     - For example, in initializing the inventory, we could have:
#
#         ```python
#         def initialize_inventory(products):
#             inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
#             return inventory
#
#         ```
# <br>
#
#
# 2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
#
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
#
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
#
# 5. Print the total price of the customer order.
#
# Your code should produce output similar to the following:
#
# ```python
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0
#
# ```

# %%
#1
products = ["tshirt", "mug", "hat", "book", "keychain"]
inventory = {product: int(input (f"Insert the {product} quantity")) for product in products}


#Print inventory
# Out:
# Insert the tshirt quantity 5
# Insert the mug quantity 9
# Insert the hat quantity 16
# Insert the book quantity 23
# Insert the keychain quantity 14

# %%
#Customer order

inventory ={product: stock - 1 if product in customer_orders else stock for product, stock in inventory.items()  }
print (inventory)
# Out:
# {'tshirt': 4, 'mug': 9, 'hat': 15, 'book': 23, 'keychain': 13}

# %%
#2
customer_order = {input("Enter the name of a product that a customer wants to order: ") for purchase in range (int(input("Enter the number of customer orders:")))}
# Out:
# Enter the number of customer orders: 2
# Enter the name of a product that a customer wants to order:  tshirt
# Enter the name of a product that a customer wants to order:  hat

# %%
#3
def total_price_calculation(customer_order):
    price_calculation = [float(input (f"Insert the {purchase} price")) for purchase in customer_order ]
    total_price = sum(price_calculation)
    return total_price

# %%
print ("The total price of the purchse is: $", total_price)
# Out:
# The total price of the purchse is: $ 89.10000000000001

# %%
print(customer_order)
# Out:
# {'tshirt', 'hat'}

# %%
total_price_calculation(customer_order)
# Out:
# Insert the mug price 13.4
# Insert the book price 5.0
# Insert the tshirt price 9.76
# Insert the hat price 19.6
# 47.760000000000005

# %%
total_price_calculation = 0
for purchase in customer_order.keys():
    total_price_calculation = total_price_calculation + float(input (f"Insert the {purchase} price"))

print (f"Total: ${total_price_calculation} ")
# Out:
# Insert the tshirt price 13
# Insert the mug price 12
# Insert the hat price 69
# Insert the book price 2
# Insert the keychain price 3
# Total: $99.0

# %%
print (total_price_calculation)
# Out:
# [True, True, True, True, True]

# %%
#2 
customer_orders = set()
number_orders = 0
number_orders = int(input("Enter the number of customer orders:"))

for purchase in range (number_orders):
    purchase = input("Enter the name of a product that a customer wants to order: ")
    customer_orders.add(purchase)
print (customer_orders)
# Out:
# Enter the number of customer orders: 3
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  tshirt
# Enter the name of a product that a customer wants to order:  keychain
# {'tshirt', 'hat', 'keychain'}

# %%
#1
products = ["tshirt", "mug", "hat", "book", "keychain"]

inventory = {}

for listed_product in products:
    inventory [listed_product] = int(input (f"Insert the {listed_product} quantity"))

customer_orders = set()

# %%
products = ["tshirt", "mug", "hat", "book", "keychain"]
inventory = {product: int(input (f"Insert the {product} quantity")) for product in products}
# Out:
# Insert the tshirt quantity 15
# Insert the mug quantity 17
# Insert the hat quantity 16
# Insert the book quantity 85
# Insert the keychain quantity 32

# %%
price_calculation = [float(input (f"Insert the {purchase} price")) for purchase in customer_order.keys() ]
total_price = sum(price_calculation)
print (total_price)
# Out:
# Insert the tshirt price 16
# Insert the mug price 33.2
# Insert the hat price 15.9
# Insert the book price 16
# Insert the keychain price 8
# 89.10000000000001

# %%
customer_orders = set()
add_prod = input ("Do you want to add a product? y/n").lower()
while add_prod == "y":
    input_prod = input(("Type a product:"))
    while input_prod not in products:
        print ("¡NOT VALID!")
        input_prod = input("Type a product: ").lower()
    else :
        customer_orders.add(input_prod)
        add_prod = input ("Do you want to add a product? y/n").lower()
else:
    print("BYE!")
# Out:
# Do you want to add a product? y/n y
# Type a product: mug
# Do you want to add a product? y/n y
# Type a product: hat
# Do you want to add a product? y/n y
# Type a product: book
# Do you want to add a product? y/n n
# BYE!

# %%
print_inventory ={product:inventory[product] for product in inventory}

# %%
inventory ={product: stock - 1  if product in customer_orders else stock for product, stock in inventory.items()}

# %%
inventory = {product: stock for product, stock in inventory.items() print (inventory)}
# Out:
#   Cell In[15], line 1
#     inventory = {product: stock for product, stock in inventory.items() print (inventory)}
#                                                                         ^
# SyntaxError: invalid syntax
